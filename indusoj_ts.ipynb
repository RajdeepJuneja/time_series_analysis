# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
import datetime
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\bhara\Documents\indusos\indusoj.csv",nrows = 20000000,encoding='ISO-8859-1',header=None)
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#                  0                    1                    2      3
# 0  450911004203547  2017-02-20 05:59:49  2017-02-19 19:57:17    456
# 1  450911023047547  2017-02-20 06:42:23  2017-02-20 06:36:27    535
# 2  450911273568547  2017-02-20 07:36:19  2017-02-20 07:25:53   2300
# 3  450911202369547  2017-02-20 08:19:01  2017-02-20 08:09:19  11040
# 4  450911296106547  2017-02-20 05:30:40  2017-02-19 14:43:20   5241

# %%
data.columns =["ID","ds","Server_sink","Amount"]

# %%
data.head()
# Out:
#                 ID                   ds          Server_sink  Amount
# 0  450911004203547  2017-02-20 05:59:49  2017-02-19 19:57:17     456
# 1  450911023047547  2017-02-20 06:42:23  2017-02-20 06:36:27     535
# 2  450911273568547  2017-02-20 07:36:19  2017-02-20 07:25:53    2300
# 3  450911202369547  2017-02-20 08:19:01  2017-02-20 08:09:19   11040
# 4  450911296106547  2017-02-20 05:30:40  2017-02-19 14:43:20    5241

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000000 entries, 0 to 19999999
# Data columns (total 4 columns):
# ID             object
# ds             object
# Server_sink    object
# Amount         int64
# dtypes: int64(1), object(3)
# memory usage: 610.4+ MB

# %%
data.drop(['Server_sink'],axis=1,inplace=True)

# %%
#data.head()

# %%
#data.set_index('ds', inplace=True)

# %%
#data.head()

# %%
data["ds"]=pd.to_datetime(data["ds"])

# %%
data["year"] = data["ds"].dt.year
data["month"] = data["ds"].dt.strftime('%b')
data.head()
# Out:
#                 ID                  ds  Amount  year month
# 0  450911004203547 2017-02-20 05:59:49     456  2017   Feb
# 1  450911023047547 2017-02-20 06:42:23     535  2017   Feb
# 2  450911273568547 2017-02-20 07:36:19    2300  2017   Feb
# 3  450911202369547 2017-02-20 08:19:01   11040  2017   Feb
# 4  450911296106547 2017-02-20 05:30:40    5241  2017   Feb

# %%
#data.set_index('ds', inplace=True)

# %%
#data.tail()
# Out:
#                        ID                  ds  Amount  year month
# 19999995  609911349923527 2017-05-18 21:10:33       4  2017   May
# 19999996  550911194441552 2017-05-18 20:34:47       1  2017   May
# 19999997  600911271542549 2017-05-18 21:45:11    2447  2017   May
# 19999998  600911749780514 2017-05-18 21:40:17     837  2017   May
# 19999999     911032715555 2017-05-18 21:34:02     400  2017   May

# %%
#count = data.groupby([data['month'],data['ID'],data['Amount']]).count()

# %%
#count.tail(10)

# %%
data.groupby('ID').filter(lambda x: x.Amount.min() > 500000)
# Out:
#                        ID                  ds   Amount  year month
# 116707    606911853208527 2017-03-24 14:23:19  1359832  2017   Mar
# 117040    606911853208527 2017-03-24 14:23:19  1359407  2017   Mar
# 119582    606911853208527 2017-03-24 14:23:19  1359572  2017   Mar
# 120899    606911853208527 2017-03-24 14:23:19  1359932  2017   Mar
# 120906    606911853208527 2017-03-24 14:23:19  1359892  2017   Mar
# 128151    606911853208527 2017-03-25 17:28:35  1358707  2017   Mar
# 135296    606911853208527 2017-03-25 14:22:50  1358967  2017   Mar
# 9078936    2017-04-27
# Name: date, dtype: object

# %%
#data1.head()
# Out:
#                       ID                  ds   Amount  year month        date
# 4869783  606911853208527 2017-04-14 09:33:31  1339017  2017   Apr  2017-04-14
# 4876692  606911853208527 2017-04-16 18:44:38  1336047  2017   Apr  2017-04-16
# 4877708  606911853208527 2017-04-16 18:44:38  1335607  2017   Apr  2017-04-16
# 4881692  606911853208527 2017-04-16 06:07:23  1336587  2017   Apr  2017-04-16
# 4904568  606911853208527 2017-04-13 15:32:15  1339717  2017   Apr  2017-04-13

# %%
#data1.set_index('ID', inplace=True)

# %%
#data1.head()

# %%
data1['date'] = data1['ds'].dt.date
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data1.drop('year',axis =1,inplace=True)
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#data1.head(10)
# Out:
#           Amount        date
# 4869783  1339017  2017-04-14
# 4876692  1336047  2017-04-16
# 4877708  1335607  2017-04-16
# 4881692  1336587  2017-04-16
# 4904568  1339717  2017-04-13
# 4917454  1348377  2017-04-07
# 4922905  1348057  2017-04-08
# 4947297  1335247  2017-04-16
# 4958521  1336747  2017-04-16
# 4965721  1338197  2017-04-14

# %%
#data1.groupby(by='date').agg('sum')

# %%
#data1.head()

# %%
data1.head()
# Out:
#                       ID                  ds   Amount month        date
# 4869783  606911853208527 2017-04-14 09:33:31  1339017   Apr  2017-04-14
# 4876692  606911853208527 2017-04-16 18:44:38  1336047   Apr  2017-04-16
# 4877708  606911853208527 2017-04-16 18:44:38  1335607   Apr  2017-04-16
# 4881692  606911853208527 2017-04-16 06:07:23  1336587   Apr  2017-04-16
# 4904568  606911853208527 2017-04-13 15:32:15  1339717   Apr  2017-04-13

# %%
#data1.reset_index()

# %%
data1.drop('ID',axis=1,inplace=True)
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data1.drop('month',axis=1,inplace=True)
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data1.drop('ds',axis=1,inplace=True)
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\pandas\core\frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data1.head()
# Out:
#           Amount        date
# 4869783  1339017  2017-04-14
# 4876692  1336047  2017-04-16
# 4877708  1335607  2017-04-16
# 4881692  1336587  2017-04-16
# 4904568  1339717  2017-04-13

# %%
#data1.reset_index()
# Out:
#       index   Amount        date
# 0   4869783  1339017  2017-04-14
# 1   4876692  1336047  2017-04-16
# 2   4877708  1335607  2017-04-16
# 3   4881692  1336587  2017-04-15
# 4   4904568  1339717  2017-04-13
# 5   4917454  1348377  2017-04-07
# 6   4922905  1348057  2017-04-08
# 7   4947297  1335247  2017-04-16
# 8   4958521  1336747  2017-04-15
# 9   4965721  1338197  2017-04-14
# 10  7518543  1331947  2017-04-19
# 11  7540838  1332807  2017-04-18
# 12  7542424  1333787  2017-04-17
# 13  7546896  1333407  2017-04-18
# 14  7556197  1331562  2017-04-20
# 15  7559260  1331722  2017-04-20
# 16  7560974  1331602  2017-04-20
# 17  9048595  1328822  2017-04-23
# 18  9050780  1328842  2017-04-23
# 19  9056476  1329262  2017-04-22
# 20  9067991  1323722  2017-04-27
Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\bhara\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(16,7))
plt.plot(data1.Amount)

# %%
from pandas.tools.plotting import autocorrelation_plot
plt.figure(figsize=(16, 7))
plot_lags= 25
autocorrelation_plot(data1.Amount)
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: 'pandas.tools.plotting.autocorrelation_plot' is deprecated, import 'pandas.plotting.autocorrelation_plot' instead.
#   after removing the cwd from sys.path.

# %%
data1 = data1.resample('D').mean()

# %%
decompose = pd.DataFrame(data1.Amount)
decompose.index = data1.index
decompose.head()
# Out:
#                Amount
# ds
# 2017-04-07  1348377.0
# 2017-04-08  1348057.0
# 2017-04-09        NaN
# 2017-04-10        NaN
# 2017-04-11        NaN

# %%
data1.fillna(data1.mean(), inplace=True)

# %%
#data1.isnull()

# %%
from statsmodels.tsa.stattools import adfuller

def stationarity_test(data):
    dftest = adfuller(data1.Amount, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)
    plt.figure(figsize=(16, 7))
    plt.plot(data1.index, data1.Amount)
    plt.show()

stationarity_test(data1)  # Test stats is high as compare to criticals so data is not stationary as can see as well
# Out:
# Test Statistic                  0.584246
# p-value                         0.987221
# #Lags Used                      5.000000
# Number of Observations Used    28.000000
# Critical Value (1%)            -3.688926
# Critical Value (5%)            -2.971989
# Critical Value (10%)           -2.625296
# dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test = train_test_split(data1,test_size=0.25,shuffle=False)

# %%
import math
## Now take the log (To make variance constant) and check for stationary again 
log_train = x_train
log_train = log_train["Amount"].apply(lambda x: math.log(x+1))
log_train = pd.DataFrame(log_train)
stationarity_test(log_train)
# Out:
# Test Statistic                  0.584246
# p-value                         0.987221
# #Lags Used                      5.000000
# Number of Observations Used    28.000000
# Critical Value (1%)            -3.688926
# Critical Value (5%)            -2.971989
# Critical Value (10%)           -2.625296
# dtype: float64

# %%
first_diff = log_train["Amount"] - log_train["Amount"].shift(1)
first_diff = first_diff.fillna(0)
first_diff = pd.DataFrame(first_diff)  # shift having no impact on data
stationarity_test(first_diff)
# Out:
# Test Statistic                  0.584246
# p-value                         0.987221
# #Lags Used                      5.000000
# Number of Observations Used    28.000000
# Critical Value (1%)            -3.688926
# Critical Value (5%)            -2.971989
# Critical Value (10%)           -2.625296
# dtype: float64

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf
lag_acf = acf(first_diff, nlags=20)
lag_pacf = pacf(first_diff, nlags=20, method='ols')

plt.figure(figsize=(16, 7))
#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf, marker="o")
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(first_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(first_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')


#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf, marker="o")
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(first_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(first_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
## AR Model p=1, d=1, q=0 
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(log_train, order=(1, 1, 0))  
results_AR = model.fit(disp=-1)
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# C:\Users\bhara\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# ...

# %%
from sklearn.metrics import mean_squared_error
plt.figure(figsize=(16, 7))
plt.plot(x_train.index, x_train.Amount, color="lightblue")
plt.plot(x_test.index, x_test.Amount, color="green")
## Forecasting 
pred = pd.DataFrame(results_AR.forecast(len(x_test))[0])
pred.columns = ["yhat"]
pred.index = x_test.index

## Converting from log to normal value
pred["yhat"] = pred["yhat"].apply(lambda x: math.exp(x)-1)

## Measuring error. 
measure = math.pow(mean_squared_error(x_test.Amount, pred.values), 0.5)
print(measure)
plt.plot(pred.index, pred.fillna(0).values, color="red")
plt.show()
# Out:
# 6959.9508766543895

# %%
from statsmodels.tsa.arima_model import ARIMA
model = ARIMA(log_train, order=(0, 1, 1))  
results_MA = model.fit(disp=-1)  


plt.figure(figsize=(16, 7))
plt.plot(x_train.index, x_train.Amount, color="lightblue")
plt.plot(x_test.index, x_test.Amount, color="green")

## Forecasting 
pred = pd.DataFrame(results_MA.forecast(len(x_test))[0])
pred.columns = ["yhat"]
pred.index = x_test.index

## Converting from log to normal value
pred["yhat"] = pred["yhat"].apply(lambda x: math.exp(x)-1)

## Measuring error. 
measure = math.pow(mean_squared_error(x_test.Amount, pred.values), 0.5)
print(measure)
plt.plot(pred.index, pred.fillna(0).values, color="red")
plt.show()
# Out:
# C:\Users\bhara\Anaconda3\lib\site-packages\scipy\signal\signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# 6972.462691211662

# %%
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
y_hat_avg = x_test.copy()
fit2 = SimpleExpSmoothing(np.asarray(x_train['Amount'])).fit(smoothing_level=0.6,optimized=False)
y_hat_avg['SES'] = fit2.forecast(len(x_test))
plt.figure(figsize=(16,8))
plt.plot(x_train['Amount'], label='Train')
plt.plot(x_test['Amount'], label='Test')
plt.plot(y_hat_avg['SES'], label='SES')
plt.legend(loc='best')
plt.show()

# %%
y_hat_avg = x_test.copy()
fit1 = ExponentialSmoothing(np.asarray(x_train['Amount']) ,seasonal_periods=7 ,trend='add', seasonal='add',).fit()
y_hat_avg['Holt_Winter'] = fit1.forecast(len(x_test))
plt.figure(figsize=(16,8))
plt.plot( x_train['Amount'], label='Train')
plt.plot(x_test['Amount'], label='Test')
plt.plot(y_hat_avg['Holt_Winter'], label='Holt_Winter')
plt.legend(loc='best')
plt.show()

# %%
from math import sqrt

rms = sqrt(mean_squared_error(x_test.Amount,y_hat_avg['Holt_Winter'] ))
print(rms)
# Out:
# 8793.995167426032

# %%
plt.figure(figsize=(16, 7))
plt.plot(x_train.index, x_train.Amount, color="lightblue")
plt.plot(x_test.index, x_test.Amount, color="green")

ets_stl = ExponentialSmoothing(x_train['Amount'] ,seasonal_periods=7 ,trend='add', seasonal='mul').fit()
## Forecasting 
pred = pd.DataFrame(ets_stl.forecast(len(x_test)))
pred.columns = ["yhat"]
pred.index = x_test.index

## Measuring error. 
measure = math.pow(mean_squared_error(x_test.Amount, pred.values), 0.5)
print(measure)
plt.plot(pred.index, pred.fillna(0).values, color="red")
plt.show()
# Out:
# 9007.486099340533
